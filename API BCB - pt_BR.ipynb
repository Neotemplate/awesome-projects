# %% [markdown]
# <a href="https://colab.research.google.com/github/Neotemplate/awesome-projects/blob/main/API%20BCB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Ainda atualizando esse notebook...***
#
# Como esse notebook usa gráficos interativos, opte por abrir no Colab para visualização.
#
# O objetivo desse notebook é poder consultar os principais indicadores disponíveis pelo Banco Central através de sua API.
#
#
# Retirado do site do BCB:
#
# **Parâmetros**:
#
# **codigo_Serie** (obrigatório): parâmetro numérico que representa o código da série a ser consultada.
#
# **dataInicial** (opcional): parâmetro textual que representa a data de início da consulta, no formato dd/MM/aaaa.
#
# **dataFinal** (opcional): parâmetro textual que representa a data final da consulta, no formato dd/MM/aaaa.
#
# O serviço permite também recuperar os N últimos valores de uma determinada série:
#
# http://api.bcb.gov.br/dados/serie/bcdata.sgs.{codigo_serie}/dados/ultimos/{N}?formato=csv
#
# Alguns exemplos de URLs:
#
# http://api.bcb.gov.br/dados/serie/bcdata.sgs.20542/dados?formato=csv&dataInicial=01/01/2010&dataFinal=31/12/2016
#
# http://api.bcb.gov.br/dados/serie/bcdata.sgs.20542/dados?formato=csv
#
# http://api.bcb.gov.br/dados/serie/bcdata.sgs.20542/dados/ultimos/10?formato=csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from datetime import date
import requests
from bs4 import BeautifulSoup

today = date.today().strftime('%d/%m/%Y')

def search_bcb(code, init_date = None, end_date = None):

  if init_date == None or end_date == None:  
    url_full = f'http://api.bcb.gov.br/dados/serie/bcdata.sgs.{code}/dados?formato=json'
    df = pd.read_json(url_full)
    return df

  else:
    url_time = f'http://api.bcb.gov.br/dados/serie/bcdata.sgs.{code}/dados?formato=json&dataInicial={init_date}&dataFinal={end_date}'
    df = pd.read_json(url_time)
    return df

# %% [markdown]
# ##Economia Real

# %%
data = search_bcb(4382)

fig = px.line(data, x="data", y="valor", line_shape="spline", render_mode="svg")
fig.update_layout(xaxis_range=[min(data.data),max(data.data)],
                  title_text='PIB acumulado dos últimos 12 meses - valores correntes',xaxis_rangeslider_visible=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = search_bcb(4192)

fig = px.line(data, x="data", y="valor", line_shape="spline", render_mode="svg")
fig.update_layout(xaxis_range=[min(data.data),max(data.data)],
                  title_text='PIB acumulado dos últimos 12 meses em dólares',xaxis_rangeslider_visible=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = search_bcb(4385)

fig = px.line(data, x="data", y="valor", line_shape="spline", render_mode="svg")
fig.update_layout(xaxis_range=[min(data.data),max(data.data)],
                  title_text='PIB mensal em dólares',xaxis_rangeslider_visible=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = search_bcb(21775)

fig = go.Figure()
fig.add_trace(go.Scatter(
                x=data.data,
                y=data.valor,
                name="PIB per capita em R$ correntes",
                line_color='deepskyblue',
                opacity=0.8))

data = search_bcb(21776)

fig.add_trace(go.Scatter(
                x=data.data,
                y=data.valor,
                name="PIB per capita em US$ correntes",
                line_color='red',
                opacity=0.8))

fig.update_layout(xaxis_range=[min(data.data),max(data.data)],
                  title_text='PIB per capita em reais e dólar', xaxis_rangeslider_visible=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = search_bcb(22704)

fig = go.Figure()
fig.add_trace(go.Scatter(
                x=data.data,
                y=data.valor,
                name="Balança comercial e Serviços - mensal - saldo",
                line_color='deepskyblue',
                opacity=0.8))

data = search_bcb(22705)

fig.add_trace(go.Scatter(
                x=data.data,
                y=data.valor,
                name="	Balança comercial e Serviços - mensal - receita",
                line_color='red',
                opacity=0.8))

data = search_bcb(22706)

fig.add_trace(go.Scatter(
                x=data.data,
                y=data.valor,
                name="	Balança comercial e Serviços - mensal - despesa",
                line_color='green',
                opacity=0.8))

fig.update_layout(xaxis_range=[min(data.data),max(data.data)],
                  title_text='Balança comercial e Serviços', xaxis_rangeslider_visible=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = search_bcb(24372)

fig = go.Figure()
fig.add_trace(go.Scatter(
                x=data.data,
                y=data.valor,
                name="Empregados no setor público - PNADC",
                line_color='deepskyblue',
                opacity=0.8))

data = search_bcb(24373)

fig.add_trace(go.Scatter(
                x=data.data,
                y=data.valor,
                name="Empregado por conta própria - PNADC",
                line_color='red',
                opacity=0.8))

data = search_bcb(24375)

fig.add_trace(go.Scatter(
                x=data.data,
                y=data.valor,
                name="Empregados no setor privado - Com carteira - PNADC",
                line_color='green',
                opacity=0.8))

data = search_bcb(24376)

fig.add_trace(go.Scatter(
                x=data.data,
                y=data.valor,
                name="Empregados no setor privado - Sem Carteira - PNADC",
                line_color='pink',
                opacity=0.8))

data = search_bcb(24377)

fig.add_trace(go.Scatter(
                x=data.data,
                y=data.valor,
                name="Empregados no setor privado - Total - PNADC",
                line_color='black',
                opacity=0.8))


fig.update_layout(xaxis_range=[min(data.data),max(data.data)],
                  title_text='Mercado de trabalho', xaxis_rangeslider_visible=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = search_bcb(433, '01/08/1995', today)

fig = go.Figure()
fig.add_trace(go.Scatter(
                x=data.data,
                y=data.valor,
                name="Índice nacional de preços ao consumidor-amplo (IPCA)",
                line_color='deepskyblue',
                opacity=0.8))

fig.update_layout(xaxis_range=[min(data.data),max(data.data)],
                  title_text='Índice nacional de preços ao consumidor-amplo (IPCA) - Var. % mensal', xaxis_rangeslider_visible=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = search_bcb(1403)

fig = go.Figure()
fig.add_trace(go.Scatter(
                x=data.data,
                y=data.valor,
                name="Consumo de Energia Elétrica Brasil - Residencial",
                line_color='green',
                opacity=0.8))

data = search_bcb(1404)

fig.add_trace(go.Scatter(
                x=data.data,
                y=data.valor,
                name="Consumo de Energia Elétrica Brasil - Industrial",
                line_color='red',
                opacity=0.8))

fig.update_layout(xaxis_range=[min(data.data),max(data.data)],
                  title_text='Consumo de energia elétrica - Residencial e Industrial', xaxis_rangeslider_visible=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##Finanças Públicas

# %%
data = search_bcb(4504)

fig = go.Figure()
fig.add_trace(go.Scatter(
                x=data.data,
                y=data.valor,
                name="Dívida líquida do setor público - total",
                line_color='deepskyblue',
                opacity=0.8))

data = search_bcb(4515)

fig.add_trace(go.Scatter(
                x=data.data,
                y=data.valor,
                name="Dívida líquida do setor público - interna",
                line_color='red',
                opacity=0.8))

data = search_bcb(4526)

fig.add_trace(go.Scatter(
                x=data.data,
                y=data.valor,
                name="Dívida líquida do setor público - externa",
                line_color='green',
                opacity=0.8))

fig.update_layout(xaxis_range=[min(data.data),max(data.data)],
                  title_text='Dívida líquida do setor público - total (% PIB)',xaxis_rangeslider_visible=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = search_bcb(10829)

fig = px.line(data, x="data", y="valor", line_shape="spline", render_mode="svg")
fig.update_layout(xaxis_range=[min(data.data),max(data.data)],
                  title_text='Dívida fiscal líquida com câmbio',xaxis_rangeslider_visible=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##Taxa de juros - CDI

# %%
data = search_bcb(4389, '13/09/1994', today)

fig = px.line(data, x="data", y="valor", line_shape="spline", render_mode="svg")
fig.update_layout(xaxis_range=[min(data.data),max(data.data)],
                  title_text='Taxa de juros - CDI anualizada base 252',xaxis_rangeslider_visible=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
